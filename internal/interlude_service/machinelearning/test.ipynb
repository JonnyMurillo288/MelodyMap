# %%
import pickletools

with open("./feature_engineering/features/prep.pkl", "rb") as f:
    pickletools.dis(f.read())
# Out:
#     0: \x80 PROTO      4
#     2: \x95 FRAME      434
#    11: \x8c SHORT_BINUNICODE '__main__'
#    21: \x94 MEMOIZE    (as 0)
#    22: \x8c SHORT_BINUNICODE 'CVAEPreprocessor'
#    40: \x94 MEMOIZE    (as 1)
#    41: \x93 STACK_GLOBAL
#    42: \x94 MEMOIZE    (as 2)
#    43: )    EMPTY_TUPLE
#    44: \x81 NEWOBJ
#    45: \x94 MEMOIZE    (as 3)
#    46: }    EMPTY_DICT
#    47: \x94 MEMOIZE    (as 4)
#    48: (    MARK
#    49: \x8c     SHORT_BINUNICODE 'c_imputer'
#    60: \x94     MEMOIZE    (as 5)
#    61: \x8c     SHORT_BINUNICODE 'sklearn.impute._base'
#    83: \x94     MEMOIZE    (as 6)
#    84: \x8c     SHORT_BINUNICODE 'SimpleImputer'
#    99: \x94     MEMOIZE    (as 7)
#   100: \x93     STACK_GLOBAL
#   101: \x94     MEMOIZE    (as 8)
#   102: )        EMPTY_TUPLE
#   103: \x81     NEWOBJ
#   104: \x94     MEMOIZE    (as 9)
#   105: }        EMPTY_DICT
#   106: \x94     MEMOIZE    (as 10)
#   107: (        MARK
#   108: \x8c         SHORT_BINUNICODE 'missing_values'
# ...
